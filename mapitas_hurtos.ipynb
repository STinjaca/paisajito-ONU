# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("./DATA/seguridad/hurto_a_persona_medata.csv", encoding='latin1', sep=';')
df
# Out:
#         Columna1                                     stage       fecha_hecho  \
# 0           1077  327fecb7d30200c5d507652ca7a3b567f7a2f74f  18/02/2020 14:30
# 1           1078  34e358136f57411ad7cfbc93c44ab255c93e018e   15/01/2020 7:30
# 2           1079  09001a164dcdc04901ca7ebc2b6c3e3cfdd9fc89    7/07/2020 6:00
# 3           1080  090b4f4620cd3fd645ca70892ad457c738cf6706  27/12/2020 17:00
# 4           1081  0995e048dae91a04511f1f875f50b16fbc0e820b  27/11/2020 21:30
# ...          ...                                       ...               ...
# 231006    586878      7bd1d646-0c56-4363-82d5-b2881575a34e    8/07/2023 0:30
# 231007    586879      5e0b6d0a-f519-44c5-b224-43e6403c74f5    8/07/2023 3:30
# 231008    586880      489ac875-ce4f-4a4e-a09d-7ad8831cb0f5    9/07/2023 6:30
# 231009    586881      53c224cf-0201-48f1-94c1-227fd86d83f4  10/07/2023 13:00
# 231010    586882      a641ffb8-a25e-4775-ab65-1d97e95a7007  10/07/2023 13:30
#
# ...

# %%
df_agrupado = df.groupby("nombre_barrio").count()

df_agrupado.sort_values("codigo_comuna", inplace=True)
df_agrupado.tail(6)
# Out:
#                Columna1  stage  fecha_hecho  latitud  longitud  cantidad  \
# nombre_barrio
# Barrio Colón       3945   3945         3945     3734      3734      3945
# Laureles           4021   4021         4021     2517      2517      4021
# Guayaquil          4647   4647         4647     4325      4325      4647
# El Poblado         7001   7001         7001     4319      4319      7001
# Sin dato          16119  16119        16119       60        60     16119
# La Candelaria     23637  23637        23637    18821     18821     23637
#
#                   id  codigo_barrio  codigo_comuna  lugar  ...  \
# nombre_barrio                                              ...
# Barrio Colón    3945           3945           3945   3945  ...
# Laureles        4021           4021           4021   4021  ...
# Guayaquil       4647           4647           4647   4647  ...
# El Poblado      7001           7001           7001   7001  ...
# ...

# %%
df_agrupado = df.groupby("nombre_barrio")
df_agrupado.get_group("La Candelaria")["bien"].value_counts()
# Out:
# bien
# Celular                         7747
# Sin dato                        4873
# Peso                            3336
# Cédula                          1571
# Tarjeta bancaria                 881
#                                 ...
# Medicamento antiinflamatorio       1
# Telex                              1
# Prendedor                          1
# Sin dato electrodomésticos         1
# Material de intendencia            1
# Name: count, Length: 205, dtype: int64
